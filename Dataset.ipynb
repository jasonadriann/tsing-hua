# %%
import os
import fiftyone as fo

ROOT_DIR = os.path.dirname(os.path.abspath(''))
print(ROOT_DIR)
DATA_DIR = os.path.join(ROOT_DIR, 'Tsing-hua/low-resolution')
print(DATA_DIR)
TRAINVAL_DIR = os.path.join(ROOT_DIR, 'Tsing-hua/TrainAndValList')
print(TRAINVAL_DIR)
# Out:
# c:\jason\semester 8\Magang
# c:\jason\semester 8\Magang\Tsing-hua/low-resolution
# c:\jason\semester 8\Magang\Tsing-hua/TrainAndValList

# %%
# Create an empty dataset
dataset = fo.Dataset()

# %%
# session.selected

# %%
# Initialize an empty array to store folder names
class_names = []

# Iterate over the folders in the directory
for entry in os.scandir(DATA_DIR):
    if entry.is_dir():
        class_names.append(entry.name)

# Print the folder names
print(class_names)
# Out:
# ['1043-n000001-Shiba_Dog', '1121-n000002-French_bulldog', '1160-n000003-Siberian_husky', '1324-n000004-malamute', '1936-n000005-Pomeranian', '200-n000008-Airedale', '200-n000010-miniature_poodle', '200-n000012-affenpinscher', '201-n000024-schipperke', '202-n000020-Australian_terrier', '202-n000023-Welsh_springer_spaniel', '202-n000028-curly_coated_retriever', '203-n000015-Staffordshire_bullterrier', '203-n000016-Norwich_terrier', '203-n000021-Tibetan_terrier', '203-n000022-English_setter', '203-n000027-Norfolk_terrier', '205-n000029-Pembroke', '205-n000030-Tibetan_mastiff', '206-n000007-Border_terrier', '206-n000035-Great_Dane', '206-n000037-Scotch_terrier', '206-n000047-flat_coated_retriever', '206-n000051-Saluki', '207-n000011-Irish_setter', '207-n000026-Blenheim_spaniel', '207-n000036-Irish_terrier', '207-n000044-bloodhound', '207-n000045-redbone', '209-n000040-West_Highland_white_terrier', '209-n000042-Brabancon_griffo', '209-n000043-dhole', '209-n000049-kelpie', '209-n000054-Doberman', '210-n000006-Ibizan_hound', '210-n000048-vizsla', '211-n000009-cairn', '211-n000018-German_shepherd', '211-n000025-African_hunting_dog', '211-n000052-Dandie_Dinmont', '211-n000058-Sealyham_terrier', '211-n000059-German_short_haired_pointer', '211-n000061-Bernese_mountain_dog', '211-n000068-Saint_Bernard', '214-n000019-Leonberg', '214-n000033-Bedlington_terrier', '215-n000031-Newfoundland', '215-n000038-Lhasa', '215-n000075-Chesapeake_Bay_retriever', '216-n000017-Lakeland_terrier', '216-n000063-Walker_hound', '216-n000078-American_Staffordshire_terrier', '217-n000014-otterhound', '217-n000034-Sussex_spaniel', '217-n000046-Norwegian_elkhound', '217-n000050-bluetick', '217-n000079-dingo', '219-n000066-Irish_water_spaniel', '2192-n000088-Samoyed', '220-n000032-Fila Braziliero', '220-n000053-standard_schnauzer', '220-n000069-Mexican_hairless', '221-n000055-EntleBucher', '222-n000013-Afghan_hound', '223-n000067-kuvasz', '223-n000074-English_foxhound', '223-n000092-keeshond', '224-n000039-Irish_wolfhound', '224-n000056-Scottish_deerhound', '224-n000060-Rottweiler', '225-n000062-black_and_tan_coonhound', '225-n000073-Great_Pyrenees', '225-n000082-boxer', '226-n000057-wire_haired_fox_terrier', '226-n000064-borzoi', '227-n000070-groenendael', '227-n000094-collie', '228-n000085-Gordon_setter', '229-n000087-Kerry_blue_terrier', '230-n000041-briard', '230-n000080-Rhodesian_ridgeback', '230-n000084-Boston_bull', '231-n000077-bull_mastiff', '231-n000081-silky_terrier', '232-n000076-Brittany_spaniel', '232-n000083-Eskimo_dog', '232-n000089-giant_schnauzer', '233-n000071-malinois', '233-n000072-Bouvier_des_Flandres', '234-n000065-whippet', '234-n000091-Appenzeller', '234-n000093-Chinese_Crested_Dog', '2342-n000102-miniature_schnauzer', '235-n000090-soft_coated_wheaten_terrier', '235-n000096-Weimaraner', '235-n000097-clumber', '237-n000086-Greater_Swiss_Mountain_dog', '237-n000095-toy_terrier', '238-n000099-Italian_greyhound', '241-n000100-basset', '243-n000103-basenji', '245-n000098-Australian_Shepherd', '249-n000101-Maltese_dog', '249-n000106-Japanese_spaniel', '253-n000105-Cane_Carso', '253-n000107-Japanese_Spitzes', '257-n000108-Old_English_sheepdog', '258-n000104-Black_sable', '2594-n000109-Border_collie', '274-n000110-Shetland_sheepdog', '276-n000112-English_springer', '276-n000113-beagle', '286-n000111-cocker_spaniel', '2909-n000116-Cardigan', '2925-n000114-toy_poodle', '3083-n000117-Bichon_Frise', '316-n000118-standard_poodle', '318-n000115-komondor', '329-n000119-chow', '3336-n000121-chinese_rural_dog', '340-n000120-Yorkshire_terrier', '3580-n000122-Labrador_retriever', '361-n000123-Shih_Tzu', '420-n000124-Chihuahua', '480-n000125-Pekinese', '5355-n000126-golden_retriever', '561-n000127-miniature_pinscher', '7449-n000128-teddy', '798-n000130-pug', '806-n000129-papillon']

# %%
data_split_count = {name:0 for name in class_names}

for name in data_split_count.keys():
    data_split_count[name] = len(os.listdir(os.path.join(DATA_DIR, name)))

print(data_split_count)
# Out:
# {'1043-n000001-Shiba_Dog': 1043, '1121-n000002-French_bulldog': 1121, '1160-n000003-Siberian_husky': 1160, '1324-n000004-malamute': 1324, '1936-n000005-Pomeranian': 1936, '200-n000008-Airedale': 200, '200-n000010-miniature_poodle': 200, '200-n000012-affenpinscher': 200, '201-n000024-schipperke': 201, '202-n000020-Australian_terrier': 202, '202-n000023-Welsh_springer_spaniel': 202, '202-n000028-curly_coated_retriever': 202, '203-n000015-Staffordshire_bullterrier': 203, '203-n000016-Norwich_terrier': 203, '203-n000021-Tibetan_terrier': 203, '203-n000022-English_setter': 203, '203-n000027-Norfolk_terrier': 203, '205-n000029-Pembroke': 205, '205-n000030-Tibetan_mastiff': 205, '206-n000007-Border_terrier': 206, '206-n000035-Great_Dane': 206, '206-n000037-Scotch_terrier': 206, '206-n000047-flat_coated_retriever': 206, '206-n000051-Saluki': 206, '207-n000011-Irish_setter': 207, '207-n000026-Blenheim_spaniel': 207, '207-n000036-Irish_terrier': 207, '207-n000044-bloodhound': 207, '207-n000045-redbone': 207, '209-n000040-West_Highland_white_terrier': 209, '209-n000042-Brabancon_griffo': 209, '209-n000043-dhole': 209, '209-n000049-kelpie': 209, '209-n000054-Doberman': 209, '210-n000006-Ibizan_hound': 210, '210-n000048-vizsla': 210, '211-n000009-cairn': 211, '211-n000018-German_shepherd': 211, '211-n000025-African_hunting_dog': 211, '211-n000052-Dandie_Dinmont': 211, '211-n000058-Sealyham_terrier': 211, '211-n000059-German_short_haired_pointer': 211, '211-n000061-Bernese_mountain_dog': 211, '211-n000068-Saint_Bernard': 211, '214-n000019-Leonberg': 214, '214-n000033-Bedlington_terrier': 214, '215-n000031-Newfoundland': 215, '215-n000038-Lhasa': 215, '215-n000075-Chesapeake_Bay_retriever': 215, '216-n000017-Lakeland_terrier': 216, '216-n000063-Walker_hound': 216, '216-n000078-American_Staffordshire_terrier': 216, '217-n000014-otterhound': 217, '217-n000034-Sussex_spaniel': 217, '217-n000046-Norwegian_elkhound': 217, '217-n000050-bluetick': 217, '217-n000079-dingo': 217, '219-n000066-Irish_water_spaniel': 219, '2192-n000088-Samoyed': 2192, '220-n000032-Fila Braziliero': 220, '220-n000053-standard_schnauzer': 220, '220-n000069-Mexican_hairless': 220, '221-n000055-EntleBucher': 221, '222-n000013-Afghan_hound': 222, '223-n000067-kuvasz': 223, '223-n000074-English_foxhound': 223, '223-n000092-keeshond': 223, '224-n000039-Irish_wolfhound': 228, '224-n000056-Scottish_deerhound': 224, '224-n000060-Rottweiler': 224, '225-n000062-black_and_tan_coonhound': 225, '225-n000073-Great_Pyrenees': 225, '225-n000082-boxer': 225, '226-n000057-wire_haired_fox_terrier': 226, '226-n000064-borzoi': 226, '227-n000070-groenendael': 227, '227-n000094-collie': 227, '228-n000085-Gordon_setter': 228, '229-n000087-Kerry_blue_terrier': 229, '230-n000041-briard': 230, '230-n000080-Rhodesian_ridgeback': 230, '230-n000084-Boston_bull': 230, '231-n000077-bull_mastiff': 231, '231-n000081-silky_terrier': 231, '232-n000076-Brittany_spaniel': 232, '232-n000083-Eskimo_dog': 232, '232-n000089-giant_schnauzer': 232, '233-n000071-malinois': 233, '233-n000072-Bouvier_des_Flandres': 233, '234-n000065-whippet': 234, '234-n000091-Appenzeller': 234, '234-n000093-Chinese_Crested_Dog': 234, '2342-n000102-miniature_schnauzer': 2342, '235-n000090-soft_coated_wheaten_terrier': 235, '235-n000096-Weimaraner': 235, '235-n000097-clumber': 235, '237-n000086-Greater_Swiss_Mountain_dog': 237, '237-n000095-toy_terrier': 237, '238-n000099-Italian_greyhound': 238, '241-n000100-basset': 241, '243-n000103-basenji': 243, '245-n000098-Australian_Shepherd': 245, '249-n000101-Maltese_dog': 249, '249-n000106-Japanese_spaniel': 249, '253-n000105-Cane_Carso': 253, '253-n000107-Japanese_Spitzes': 253, '257-n000108-Old_English_sheepdog': 257, '258-n000104-Black_sable': 258, '2594-n000109-Border_collie': 2594, '274-n000110-Shetland_sheepdog': 274, '276-n000112-English_springer': 276, '276-n000113-beagle': 276, '286-n000111-cocker_spaniel': 286, '2909-n000116-Cardigan': 2909, '2925-n000114-toy_poodle': 2925, '3083-n ...

# %%
train_list_path = os.path.join(TRAINVAL_DIR, 'train.lst')

with open(train_list_path, "r") as f:
    lst_contents = f.readlines()

train_array_of_paths = [line.strip() for line in lst_contents]

train_file_paths = []

for img_path in train_array_of_paths:
    joined_path = DATA_DIR + img_path[2:]
    train_file_paths.append(joined_path)

# %%
val_list_path = os.path.join(TRAINVAL_DIR, 'validation.lst')

with open(val_list_path, "r") as f:
    lst_contents = f.readlines()

val_array_of_paths = [line.strip() for line in lst_contents]

val_file_paths = []

for img_path in val_array_of_paths:
    joined_path = DATA_DIR + img_path[2:]
    val_file_paths.append(joined_path)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(40,6))
plt.bar(range(len(data_split_count)), list(data_split_count.values()), align='center', width=0.5)
plt.title("Data Class Distribution", fontsize=14)
plt.xticks(range(len(data_split_count)), list(data_split_count.keys()), rotation = 90, fontsize=10)
plt.show()

# %%
# Iterate over the train image directories
for image_directory in train_file_paths:
    # Load the image into FiftyOne
    sample = fo.Sample(filepath=image_directory)

    # Add the 'train' tag to the sample
    sample.tags.append("train")
    class_name = image_directory.split('/')[-2]
    sample["ground_truth"] = fo.Classification(label=class_name)
    
    dataset.add_sample(sample)

# Save the changes to the dataset
dataset.save()

# %%
# Iterate over the train image directories
for image_directory in val_file_paths:
    # Load the image into FiftyOne
    sample = fo.Sample(filepath=image_directory)

    # Add the 'train' tag and 'ground truth' label to the sample
    sample.tags.append("validation")
    class_name = image_directory.split('/')[-2]
    sample["ground_truth"] = fo.Classification(label=class_name)
    
    dataset.add_sample(sample)

# Save the changes to the dataset
dataset.save()

# %%
session = fo.launch_app(dataset)
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?notebook=True&subscription=ccbde62d-c557-4cf6-ac5a-dfcb204db8bd"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from fiftyone import ViewField as F

# Filter samples based on label attributes
filtered_samples = dataset.filter_field("ground_truth", F("label") == "241-n000100-basset")

# Iterate over the filtered samples
for sample in filtered_samples:
    # Access or perform operations on the filtered samples
    print(sample.filepath)

# %%
# train_split_images_path = []

# for name in class_names:
#     list_files = os.listdir(os.path.join(DATA_DIR, name))
#     list_files = [os.path.join(DATA_DIR, name, file) for file in list_files]
#     train_split_images_path+=list_files

# print(train_split_images_path)

rgb_mean = np.zeros(3)
rgb_std = np.zeros(3)
rgb_median = np.zeros(3)
for file in train_file_paths:
    img = cv2.imread(file)
    image_size = img.shape[:2]
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = img / 255.0
    rgb_median += np.median(img, axis=(0, 1))
    rgb_mean += np.mean(img, axis=(0, 1))
    rgb_std += np.std(img, axis=(0, 1))

train_rgb_median = rgb_median / len(train_file_paths)
train_rgb_mean = rgb_mean / len(train_file_paths)
train_rgb_std = rgb_std / len(train_file_paths)
print(f'size: {image_size}')
print(f'median: {train_rgb_median}')
print(f'mean: {train_rgb_mean}')
print(f'std: {train_rgb_std}')

# %%
import cv2
import numpy as np

# Load the image
image = cv2.imread(train_file_paths[0])

def show(img):
    plt.imshow(img)
    plt.show()

# Define the desired width and height
desired_width = 256
desired_height = 256

# Resize the image
resized_image = cv2.resize(image, (desired_width, desired_height))

show(resized_image)

# %%
import random

import cv2
import numpy as np
import matplotlib.pyplot as plt
import torch
from torchvision import transforms

size = (440, 330)
train_rgb_median = [0.53229724, 0.49277596, 0.42660908]
train_rgb_mean = [0.51889068, 0.48611316, 0.43536804]
train_rgb_std = [0.22851204, 0.2287879,  0.23019743]

random.shuffle(train_file_paths)
train_file_paths_20 = random.choices(train_file_paths, k=20)

def visualize(image):
    shape = image.shape
    if shape[-1] != 3:
        image = np.transpose(image, (1, 2, 0))
    plt.figure(figsize=(10, 10))
    plt.axis('off')
    plt.imshow(image)

# %%
image = cv2.imread(train_file_paths_20[0])
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
visualize(image)

# %%
transformation = transforms.ColorJitter(0.3, 0.5, 0.02, 0.4)
image = cv2.imread(train_file_paths_20[0])


# Define the desired width and height
desired_width = 256
desired_height = 256

# Resize the image
image = cv2.resize(image, (desired_width, desired_height))

image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

image_pt = torch.from_numpy(image).permute((2,0,1))
image_pt = transformation(image_pt)
visualize(image_pt.numpy())

# %%
transformation = transforms.RandomSolarize(0.3)
image = cv2.imread(train_file_paths_20[0])
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_pt = torch.from_numpy(image).permute((2,0,1))
image_pt = transformation(image_pt)
visualize(image_pt.numpy())

# %%
transformation = transforms.RandomCrop((256, 256))
image = cv2.imread(train_file_paths_20[0])
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_pt = torch.from_numpy(image).permute((2,0,1))
image_pt = transformation(image_pt)
visualize(image_pt.numpy())

# %%
transformations = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomResizedCrop(384),
    transforms.ColorJitter(0.3, 0.5, 0.02, 0.4),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=train_rgb_mean, std=train_rgb_std)
])

image = cv2.imread(train_file_paths_20[0])
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_pt = transformations(image)
visualize(image_pt.numpy())

# %%
transformations = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomRotation(60),
    transforms.RandomChoice([
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(),
    ]),
    transforms.CenterCrop(384),
    transforms.RandomChoice([
        transforms.ColorJitter(0.3, 0.5, 0.02, 0.4),
        transforms.RandomPosterize(3),
    ]),
    transforms.RandomChoice([
        transforms.RandomEqualize(),
        transforms.RandomAutocontrast(),
    ]),
    transforms.ToTensor(),
    transforms.Normalize(mean=train_rgb_mean, std=train_rgb_std)
])

image = cv2.imread(train_file_paths_20[0])
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_pt = transformations(image)
visualize(image_pt.numpy())

# %%
rows = 5
cols = 4
fig, axs = plt.subplots(rows, cols, figsize=(25,30))
axs = axs.ravel().tolist()

for idx, file_path in enumerate(train_file_paths_20):
    image = cv2.imread(file_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = transformations(image).numpy()
    image = np.transpose(image, (1, 2, 0))
    class_name = file_path.split('/')[-2]
    axs[idx].imshow(image)
    axs[idx].set_title(class_name, pad = 10)

fig.suptitle("Image from each class", y=1.05, fontsize=30)
plt.setp(axs, xticks=[],yticks=[])
plt.tight_layout()

# %%
transformations = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomRotation(60),
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.5)),
    transforms.CenterCrop(384),
    transforms.ToTensor(),
    transforms.Normalize(mean=train_rgb_mean, std=train_rgb_std)
])

image = cv2.imread(train_file_paths_20[0])
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_pt = transformations(image)
visualize(image_pt.numpy())

# %%
transformations = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.8)),
    transforms.RandomRotation(60),
    transforms.CenterCrop(384),
    transforms.ToTensor(),
    transforms.Normalize(mean=train_rgb_mean, std=train_rgb_std)
])

image = cv2.imread(train_file_paths_20[0])
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_pt = transformations(image)
visualize(image_pt.numpy())

# %%
transformations = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.8)),
    transforms.RandomRotation(60),
        transforms.RandomChoice([
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(),
    ]),
    transforms.CenterCrop(384),
    transforms.ToTensor(),
    transforms.Normalize(mean=train_rgb_mean, std=train_rgb_std)
])

image = cv2.imread(train_file_paths_20[0])
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_pt = transformations(image)
visualize(image_pt.numpy())
